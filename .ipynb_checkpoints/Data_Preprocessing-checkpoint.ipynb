# %% [markdown]
# # Data Preprocessing

# %%
import os
import cv2
import numpy as np
from albumentations import (
    HorizontalFlip, RandomCrop, Rotate, RandomBrightnessContrast,
    GaussNoise, HueSaturationValue, MotionBlur, Compose
)
import albumentations as A

augmentation = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.RandomCrop(width=100, height=100, p=0.3),
    A.Rotate(limit=15, p=0.5),
    A.GaussNoise(p=0.2), 
    A.MotionBlur(blur_limit=3, p=0.2),
    A.HueSaturationValue(hue_shift_limit=25, sat_shift_limit=25, p=0.5),
    A.RandomBrightnessContrast(brightness_limit=0.25, contrast_limit=0.25, p=0.5)
])

input_folder = './Data/Split/train'
output_folder = './Data/Split/train_augmented'
os.makedirs(output_folder, exist_ok=True)

def augment_image(image_path, output_path, num_augmentations=2):
    image = cv2.imread(image_path)
    if image is None:
        print(f"Error: Unable to read image {image_path}")
        return
    
    for i in range(num_augmentations):
        augmented = augmentation(image=image)
        augmented_image = augmented['image']
        
        output_filename = os.path.join(output_path, f"aug_{i}_{os.path.basename(image_path)}")
        cv2.imwrite(output_filename, augmented_image)
        print(f"Saved augmented image to: {output_filename}")

for class_name in os.listdir(input_folder):
    class_input_path = os.path.join(input_folder, class_name)
    class_output_path = os.path.join(output_folder, class_name)
    os.makedirs(class_output_path, exist_ok=True)
    
    for image_name in os.listdir(class_input_path):
        image_path = os.path.join(class_input_path, image_name)
        augment_image(image_path, class_output_path)
# Out:
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_0_A-01.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_1_A-01.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_0_A-02.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_1_A-02.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_0_A-05.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_1_A-05.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_0_A-06.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_1_A-06.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_0_A-07.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_1_A-07.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_0_A-08.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_1_A-08.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_0_A-09.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_1_A-09.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_0_A-13.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_1_A-13.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_0_A-14.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_1_A-14.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_0_A-15.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_1_A-15.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_0_A-17.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_1_A-17.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_0_A-18.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_1_A-18.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_0_A-19.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_1_A-19.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_0_A-20.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_1_A-20.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_0_A-21.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_1_A-21.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_0_A-22.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_1_A-22.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_0_A-23.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_1_A-23.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_0_A-24.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_1_A-24.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_0_A-25.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_1_A-25.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_0_A-26.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_1_A-26.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_0_A-27.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_1_A-27.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_0_A-29.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_1_A-29.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_0_A-30.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_1_A-30.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_0_A-31.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_1_A-31.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_0_A-32.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_1_A-32.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_0_A-33.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_1_A-33.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_0_A-34.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_1_A-34.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_0_A-35.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_1_A-35.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_0_A-36.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_1_A-36.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_0_A-37.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_1_A-37.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_0_A-38.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_1_A-38.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_0_A-39.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_1_A-39.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_0_A-41.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_1_A-41.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_0_A-42.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_1_A-42.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_0_A-43.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_1_A-43.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_0_A-45.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_1_A-45.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_0_A-47.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_1_A-47.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_0_A-48.jpg
# Saved augmented image to: ./Data/Split/train_augmented\A\aug_1_A-48.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_0_B-03.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_1_B-03.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_0_B-04.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_1_B-04.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_0_B-05.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_1_B-05.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_0_B-06.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_1_B-06.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_0_B-07.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_1_B-07.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_0_B-08.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_1_B-08.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_0_B-09.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_1_B-09.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_0_B-10.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_1_B-10.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_0_B-11.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_1_B-11.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_0_B-13.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_1_B-13.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_0_B-14.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_1_B-14.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_0_B-15.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_1_B-15.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_0_B-16.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_1_B-16.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_0_B-17.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_1_B-17.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_0_B-18.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_1_B-18.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_0_B-20.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_1_B-20.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_0_B-21.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_1_B-21.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_0_B-22.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_1_B-22.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_0_B-23.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_1_B-23.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_0_B-24.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_1_B-24.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_0_B-25.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_1_B-25.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_0_B-26.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_1_B-26.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_0_B-28.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_1_B-28.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_0_B-29.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_1_B-29.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_0_B-30.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_1_B-30.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_0_B-33.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_1_B-33.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_0_B-35.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_1_B-35.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_0_B-36.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_1_B-36.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_0_B-38.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_1_B-38.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_0_B-39.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_1_B-39.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_0_B-40.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_1_B-40.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_0_B-41.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_1_B-41.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_0_B-42.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_1_B-42.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_0_B-43.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_1_B-43.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_0_B-45.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_1_B-45.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_0_B-46.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_1_B-46.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_0_B-47.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_1_B-47.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_0_B-48.jpg
# Saved augmented image to: ./Data/Split/train_augmented\B\aug_1_B-48.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_0_C-01.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_1_C-01.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_0_C-02.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_1_C-02.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_0_C-04.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_1_C-04.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_0_C-05.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_1_C-05.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_0_C-06.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_1_C-06.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_0_C-08.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_1_C-08.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_0_C-09.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_1_C-09.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_0_C-10.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_1_C-10.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_0_C-11.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_1_C-11.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_0_C-12.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_1_C-12.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_0_C-13.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_1_C-13.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_0_C-14.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_1_C-14.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_0_C-15.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_1_C-15.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_0_C-17.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_1_C-17.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_0_C-19.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_1_C-19.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_0_C-20.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_1_C-20.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_0_C-21.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_1_C-21.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_0_C-23.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_1_C-23.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_0_C-25.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_1_C-25.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_0_C-26.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_1_C-26.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_0_C-28.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_1_C-28.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_0_C-30.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_1_C-30.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_0_C-31.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_1_C-31.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_0_C-32.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_1_C-32.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_0_C-33.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_1_C-33.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_0_C-34.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_1_C-34.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_0_C-35.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_1_C-35.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_0_C-36.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_1_C-36.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_0_C-37.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_1_C-37.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_0_C-38.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_1_C-38.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_0_C-39.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_1_C-39.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_0_C-41.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_1_C-41.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_0_C-42.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_1_C-42.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_0_C-43.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_1_C-43.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_0_C-44.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_1_C-44.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_0_C-45.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_1_C-45.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_0_C-46.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_1_C-46.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_0_C-48.jpg
# Saved augmented image to: ./Data/Split/train_augmented\C\aug_1_C-48.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_0_D-01.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_1_D-01.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_0_D-02.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_1_D-02.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_0_D-03.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_1_D-03.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_0_D-04.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_1_D-04.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_0_D-05.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_1_D-05.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_0_D-06.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_1_D-06.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_0_D-07.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_1_D-07.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_0_D-08.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_1_D-08.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_0_D-09.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_1_D-09.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_0_D-10.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_1_D-10.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_0_D-11.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_1_D-11.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_0_D-13.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_1_D-13.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_0_D-15.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_1_D-15.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_0_D-16.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_1_D-16.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_0_D-17.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_1_D-17.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_0_D-20.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_1_D-20.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_0_D-21.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_1_D-21.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_0_D-22.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_1_D-22.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_0_D-23.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_1_D-23.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_0_D-24.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_1_D-24.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_0_D-25.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_1_D-25.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_0_D-27.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_1_D-27.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_0_D-28.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_1_D-28.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_0_D-29.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_1_D-29.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_0_D-31.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_1_D-31.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_0_D-32.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_1_D-32.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_0_D-33.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_1_D-33.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_0_D-35.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_1_D-35.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_0_D-36.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_1_D-36.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_0_D-37.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_1_D-37.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_0_D-38.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_1_D-38.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_0_D-39.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_1_D-39.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_0_D-40.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_1_D-40.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_0_D-42.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_1_D-42.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_0_D-43.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_1_D-43.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_0_D-45.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_1_D-45.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_0_D-46.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_1_D-46.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_0_D-48.jpg
# Saved augmented image to: ./Data/Split/train_augmented\D\aug_1_D-48.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_0_E-01.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_1_E-01.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_0_E-04.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_1_E-04.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_0_E-06.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_1_E-06.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_0_E-07.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_1_E-07.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_0_E-08.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_1_E-08.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_0_E-09.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_1_E-09.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_0_E-10.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_1_E-10.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_0_E-11.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_1_E-11.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_0_E-13.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_1_E-13.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_0_E-14.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_1_E-14.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_0_E-16.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_1_E-16.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_0_E-17.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_1_E-17.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_0_E-18.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_1_E-18.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_0_E-19.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_1_E-19.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_0_E-20.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_1_E-20.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_0_E-21.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_1_E-21.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_0_E-22.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_1_E-22.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_0_E-23.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_1_E-23.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_0_E-25.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_1_E-25.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_0_E-28.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_1_E-28.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_0_E-29.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_1_E-29.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_0_E-30.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_1_E-30.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_0_E-32.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_1_E-32.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_0_E-33.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_1_E-33.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_0_E-34.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_1_E-34.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_0_E-35.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_1_E-35.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_0_E-36.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_1_E-36.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_0_E-38.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_1_E-38.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_0_E-39.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_1_E-39.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_0_E-40.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_1_E-40.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_0_E-41.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_1_E-41.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_0_E-42.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_1_E-42.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_0_E-43.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_1_E-43.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_0_E-44.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_1_E-44.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_0_E-45.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_1_E-45.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_0_E-46.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_1_E-46.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_0_E-47.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_1_E-47.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_0_E-48.jpg
# Saved augmented image to: ./Data/Split/train_augmented\E\aug_1_E-48.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_0_F-01.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_1_F-01.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_0_F-02.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_1_F-02.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_0_F-05.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_1_F-05.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_0_F-06.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_1_F-06.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_0_F-08.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_1_F-08.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_0_F-09.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_1_F-09.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_0_F-10.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_1_F-10.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_0_F-11.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_1_F-11.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_0_F-12.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_1_F-12.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_0_F-13.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_1_F-13.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_0_F-14.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_1_F-14.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_0_F-15.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_1_F-15.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_0_F-16.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_1_F-16.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_0_F-17.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_1_F-17.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_0_F-18.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_1_F-18.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_0_F-19.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_1_F-19.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_0_F-22.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_1_F-22.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_0_F-23.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_1_F-23.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_0_F-24.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_1_F-24.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_0_F-25.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_1_F-25.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_0_F-26.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_1_F-26.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_0_F-27.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_1_F-27.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_0_F-28.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_1_F-28.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_0_F-29.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_1_F-29.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_0_F-32.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_1_F-32.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_0_F-33.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_1_F-33.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_0_F-34.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_1_F-34.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_0_F-36.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_1_F-36.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_0_F-37.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_1_F-37.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_0_F-39.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_1_F-39.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_0_F-40.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_1_F-40.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_0_F-41.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_1_F-41.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_0_F-42.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_1_F-42.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_0_F-43.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_1_F-43.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_0_F-44.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_1_F-44.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_0_F-45.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_1_F-45.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_0_F-46.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_1_F-46.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_0_F-48.jpg
# Saved augmented image to: ./Data/Split/train_augmented\F\aug_1_F-48.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_0_G-01.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_1_G-01.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_0_G-02.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_1_G-02.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_0_G-03.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_1_G-03.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_0_G-04.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_1_G-04.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_0_G-06.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_1_G-06.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_0_G-07.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_1_G-07.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_0_G-08.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_1_G-08.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_0_G-09.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_1_G-09.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_0_G-10.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_1_G-10.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_0_G-12.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_1_G-12.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_0_G-14.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_1_G-14.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_0_G-15.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_1_G-15.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_0_G-17.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_1_G-17.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_0_G-18.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_1_G-18.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_0_G-20.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_1_G-20.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_0_G-21.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_1_G-21.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_0_G-22.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_1_G-22.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_0_G-23.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_1_G-23.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_0_G-24.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_1_G-24.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_0_G-25.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_1_G-25.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_0_G-26.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_1_G-26.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_0_G-27.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_1_G-27.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_0_G-28.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_1_G-28.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_0_G-30.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_1_G-30.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_0_G-31.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_1_G-31.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_0_G-34.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_1_G-34.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_0_G-35.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_1_G-35.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_0_G-36.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_1_G-36.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_0_G-37.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_1_G-37.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_0_G-38.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_1_G-38.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_0_G-39.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_1_G-39.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_0_G-40.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_1_G-40.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_0_G-41.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_1_G-41.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_0_G-42.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_1_G-42.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_0_G-44.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_1_G-44.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_0_G-46.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_1_G-46.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_0_G-47.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_1_G-47.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_0_G-48.jpg
# Saved augmented image to: ./Data/Split/train_augmented\G\aug_1_G-48.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_0_H-03.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_1_H-03.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_0_H-04.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_1_H-04.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_0_H-05.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_1_H-05.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_0_H-06.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_1_H-06.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_0_H-07.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_1_H-07.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_0_H-08.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_1_H-08.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_0_H-10.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_1_H-10.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_0_H-11.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_1_H-11.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_0_H-12.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_1_H-12.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_0_H-13.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_1_H-13.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_0_H-16.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_1_H-16.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_0_H-17.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_1_H-17.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_0_H-18.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_1_H-18.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_0_H-19.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_1_H-19.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_0_H-20.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_1_H-20.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_0_H-21.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_1_H-21.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_0_H-22.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_1_H-22.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_0_H-23.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_1_H-23.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_0_H-24.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_1_H-24.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_0_H-25.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_1_H-25.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_0_H-26.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_1_H-26.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_0_H-28.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_1_H-28.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_0_H-29.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_1_H-29.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_0_H-30.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_1_H-30.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_0_H-31.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_1_H-31.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_0_H-32.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_1_H-32.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_0_H-33.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_1_H-33.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_0_H-34.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_1_H-34.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_0_H-36.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_1_H-36.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_0_H-37.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_1_H-37.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_0_H-38.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_1_H-38.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_0_H-39.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_1_H-39.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_0_H-41.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_1_H-41.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_0_H-42.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_1_H-42.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_0_H-43.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_1_H-43.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_0_H-45.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_1_H-45.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_0_H-46.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_1_H-46.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_0_H-47.jpg
# Saved augmented image to: ./Data/Split/train_augmented\H\aug_1_H-47.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_0_I-01.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_1_I-01.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_0_I-02.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_1_I-02.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_0_I-03.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_1_I-03.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_0_I-04.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_1_I-04.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_0_I-05.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_1_I-05.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_0_I-06.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_1_I-06.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_0_I-07.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_1_I-07.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_0_I-08.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_1_I-08.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_0_I-09.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_1_I-09.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_0_I-10.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_1_I-10.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_0_I-11.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_1_I-11.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_0_I-15.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_1_I-15.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_0_I-16.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_1_I-16.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_0_I-17.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_1_I-17.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_0_I-18.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_1_I-18.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_0_I-19.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_1_I-19.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_0_I-20.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_1_I-20.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_0_I-21.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_1_I-21.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_0_I-22.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_1_I-22.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_0_I-23.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_1_I-23.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_0_I-25.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_1_I-25.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_0_I-26.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_1_I-26.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_0_I-27.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_1_I-27.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_0_I-29.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_1_I-29.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_0_I-30.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_1_I-30.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_0_I-31.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_1_I-31.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_0_I-32.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_1_I-32.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_0_I-33.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_1_I-33.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_0_I-37.jpg
# Saved augmented image to: ./Data/Split/train_augmented\I\aug_1_I-37.jpg
# ...
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_0_X-05.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_1_X-05.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_0_X-08.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_1_X-08.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_0_X-09.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_1_X-09.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_0_X-11.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_1_X-11.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_0_X-12.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_1_X-12.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_0_X-13.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_1_X-13.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_0_X-15.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_1_X-15.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_0_X-16.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_1_X-16.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_0_X-17.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_1_X-17.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_0_X-18.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_1_X-18.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_0_X-19.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_1_X-19.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_0_X-20.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_1_X-20.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_0_X-23.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_1_X-23.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_0_X-24.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_1_X-24.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_0_X-25.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_1_X-25.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_0_X-26.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_1_X-26.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_0_X-27.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_1_X-27.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_0_X-28.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_1_X-28.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_0_X-29.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_1_X-29.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_0_X-32.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_1_X-32.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_0_X-33.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_1_X-33.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_0_X-34.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_1_X-34.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_0_X-35.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_1_X-35.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_0_X-36.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_1_X-36.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_0_X-37.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_1_X-37.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_0_X-38.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_1_X-38.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_0_X-39.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_1_X-39.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_0_X-40.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_1_X-40.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_0_X-42.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_1_X-42.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_0_X-43.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_1_X-43.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_0_X-44.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_1_X-44.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_0_X-45.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_1_X-45.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_0_X-46.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_1_X-46.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_0_X-47.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_1_X-47.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_0_X-48.jpg
# Saved augmented image to: ./Data/Split/train_augmented\X\aug_1_X-48.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_0_Y-01.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_1_Y-01.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_0_Y-02.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_1_Y-02.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_0_Y-03.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_1_Y-03.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_0_Y-04.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_1_Y-04.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_0_Y-05.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_1_Y-05.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_0_Y-06.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_1_Y-06.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_0_Y-07.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_1_Y-07.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_0_Y-08.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_1_Y-08.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_0_Y-09.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_1_Y-09.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_0_Y-10.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_1_Y-10.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_0_Y-13.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_1_Y-13.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_0_Y-14.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_1_Y-14.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_0_Y-15.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_1_Y-15.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_0_Y-16.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_1_Y-16.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_0_Y-17.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_1_Y-17.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_0_Y-18.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_1_Y-18.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_0_Y-20.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_1_Y-20.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_0_Y-21.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_1_Y-21.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_0_Y-23.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_1_Y-23.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_0_Y-24.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_1_Y-24.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_0_Y-26.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_1_Y-26.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_0_Y-27.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_1_Y-27.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_0_Y-29.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_1_Y-29.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_0_Y-30.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_1_Y-30.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_0_Y-31.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_1_Y-31.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_0_Y-32.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_1_Y-32.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_0_Y-34.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_1_Y-34.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_0_Y-35.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_1_Y-35.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_0_Y-36.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_1_Y-36.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_0_Y-37.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_1_Y-37.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_0_Y-38.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_1_Y-38.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_0_Y-40.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_1_Y-40.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_0_Y-41.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_1_Y-41.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_0_Y-42.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_1_Y-42.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_0_Y-43.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_1_Y-43.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_0_Y-44.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_1_Y-44.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_0_Y-45.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_1_Y-45.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_0_Y-48.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Y\aug_1_Y-48.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_0_Z-01.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_1_Z-01.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_0_Z-02.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_1_Z-02.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_0_Z-03.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_1_Z-03.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_0_Z-04.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_1_Z-04.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_0_Z-05.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_1_Z-05.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_0_Z-06.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_1_Z-06.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_0_Z-07.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_1_Z-07.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_0_Z-08.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_1_Z-08.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_0_Z-09.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_1_Z-09.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_0_Z-11.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_1_Z-11.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_0_Z-12.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_1_Z-12.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_0_Z-13.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_1_Z-13.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_0_Z-15.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_1_Z-15.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_0_Z-17.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_1_Z-17.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_0_Z-18.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_1_Z-18.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_0_Z-19.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_1_Z-19.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_0_Z-20.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_1_Z-20.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_0_Z-24.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_1_Z-24.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_0_Z-25.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_1_Z-25.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_0_Z-27.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_1_Z-27.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_0_Z-28.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_1_Z-28.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_0_Z-29.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_1_Z-29.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_0_Z-30.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_1_Z-30.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_0_Z-31.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_1_Z-31.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_0_Z-32.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_1_Z-32.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_0_Z-33.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_1_Z-33.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_0_Z-34.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_1_Z-34.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_0_Z-35.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_1_Z-35.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_0_Z-36.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_1_Z-36.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_0_Z-38.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_1_Z-38.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_0_Z-39.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_1_Z-39.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_0_Z-40.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_1_Z-40.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_0_Z-41.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_1_Z-41.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_0_Z-42.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_1_Z-42.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_0_Z-43.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_1_Z-43.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_0_Z-44.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_1_Z-44.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_0_Z-45.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_1_Z-45.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_0_Z-48.jpg
# Saved augmented image to: ./Data/Split/train_augmented\Z\aug_1_Z-48.jpg
