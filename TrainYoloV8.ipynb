# %% [markdown]
# ## Clone repository ultralytics

# %%
#git clone https://github.com/ultralytics/ultralytics

# %% [markdown]
# ## Make new enviroment using anaconda

# %%
# conda create -n yolov8 python=3.8 -y
# conda activate yolov8

# %% [markdown]
# ## Instal pytorch cuda for training using GPU

# %%
# conda install pytorch torchvision torchaudio pytorch-cuda=11.8 -c pytorch -c nvidia

# %% [markdown]
# ## Install dependencies

# %%
# Navigate to the cloned directory
cd ultralytics

# Install the package in editable mode for development
pip install -e .

# %% [markdown]
# ## Setting dataset location and yaml file to locate the data

# %% [markdown]
# ## Train model YoloV8

# %%
# yolo train data=data.yaml model=yolov8s.pt epochs=50 imgsz=640 batch=16

# %% [markdown]
# ## Detect Using Webcam

# %%
# yolo task=detect mode=predict model=runs\detect\train\weights\best.pt imgsz=640 source=0 show=True conf=0.4

# %% [markdown]
# ## Result

# %% [markdown]
# Result saved in Model/YoloV8/ultralytics/runs/detect/train

# %%
import pandas as pd
results_path = "Model/YoloV8/ultralytics/runs/detect/train"
history = pd.read_csv(results_path + "/results.csv")

# %%
history.tail(5)
# Out:
#     epoch     time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 45     46  5484.75         0.95474         0.40787         1.33489
# 46     47  5597.47         0.94461         0.40171         1.33224
# 47     48  5785.22         0.93486         0.39633         1.32248
# 48     49  5894.08         0.92671         0.39335         1.31354
# 49     50  6004.93         0.91663         0.39355         1.31133
#
#     metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 45               0.94502            0.95914           0.97617
# 46               0.96255            0.95294           0.97429
# 47               0.96095            0.95236           0.97482
# 48               0.96133            0.95435           0.97818
# 49               0.95998            0.95191           0.97771
#
#     metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 45              0.63962       1.25784       0.52334       1.49942  0.000036
# 46              0.63774       1.27193       0.52214       1.50813  0.000030
# 47              0.63381       1.28380       0.51461       1.51972  0.000023
# 48              0.63449       1.29297       0.52703       1.53236  0.000017
# 49              0.63555       1.28299       0.53470       1.52318  0.000010
#
#       lr/pg1    lr/pg2
# 45  0.000036  0.000036
# 46  0.000030  0.000030
# 47  0.000023  0.000023
# 48  0.000017  0.000017
# 49  0.000010  0.000010

# %% [markdown]
# ### Train result based on Evaluation Data

# %%
from IPython.display import Image, display
image_path = results_path + '/results.png'

display(Image(filename=image_path, width=800, height=600))

# %%
image_path = results_path + '/confusion_matrix_normalized.png'

display(Image(filename=image_path, width=800, height=600))

# %%
image_path = results_path + '/F1_curve.png'

display(Image(filename=image_path, width=800, height=600))

# %%
image_path = results_path + '/P_curve.png'

display(Image(filename=image_path, width=800, height=600))

# %%
image_path = results_path + '/PR_curve.png'

display(Image(filename=image_path, width=800, height=600))

# %%
image_path = results_path + '/R_curve.png'

display(Image(filename=image_path, width=800, height=600))
