# %% [markdown]
# ## Clone repository ultralytics

# %%
# git clone https://github.com/ultralytics/yolov5.git

# %% [markdown]
# ## Make new enviroment using anaconda

# %%
# conda create -n yolov8 python=3.8 -y
# conda activate yolov8

# %% [markdown]
# ## Instal pytorch cuda for training using GPU

# %%
# conda install pytorch torchvision torchaudio pytorch-cuda=11.8 -c pytorch -c nvidia

# %% [markdown]
# ## Install dependencies

# %%
# pip install -r requirements.txt
#cd yolov5

# %% [markdown]
# ## Setting dataset location and yaml file to locate the data

# %% [markdown]
# ## Train model YoloV5

# %%
# python train.py --img 640 --batch 16 --epochs 50 --data signlanguage.yaml --weights yolov5s.pt --device 0

# %% [markdown]
# ## Detect using webcam

# %%
# python detect.py --weights runs/train/exp/weights/best.pt --source 0 --img 640 --conf 0.4 --device 0

# %% [markdown]
# ## Result

# %% [markdown]
# Restul saved in Model/YoloV5/yolov5/runs/train/exp

# %%
import pandas as pd
results_path = "Model/YoloV5/yolov5/runs/train/exp"
history = pd.read_csv(results_path + "/results.csv")

# %%
history.tail(5)
# Out:
#                    epoch        train/box_loss        train/obj_loss  \
# 45                    45              0.028095              0.009327
# 46                    46              0.027559              0.009193
# 47                    47              0.027697              0.009234
# 48                    48              0.027090              0.009188
# 49                    49              0.026801              0.009270
#
#           train/cls_loss     metrics/precision        metrics/recall  \
# 45              0.010706               0.96788               0.96468
# 46              0.009923               0.96997               0.97446
# 47              0.009776               0.97534               0.97570
# 48              0.009872               0.96463               0.97256
# 49              0.009514               0.97581               0.96801
#
#          metrics/mAP_0.5  metrics/mAP_0.5:0.95          val/box_loss  \
# 45               0.98262               0.63104              0.021235
# 46               0.98559               0.64038              0.020892
# 47               0.98392               0.63644              0.020982
# 48               0.98274               0.65042              0.020669
# 49               0.98281               0.64946              0.020828
#
#             val/obj_loss          val/cls_loss                 x/lr0  \
# 45              0.004215              0.001584              0.001288
# 46              0.004143              0.001735              0.001090
# 47              0.004171              0.001661              0.000892
# 48              0.004138              0.002000              0.000694
# 49              0.004118              0.001489              0.000496
#
#                    x/lr1                 x/lr2
# 45              0.001288              0.001288
# 46              0.001090              0.001090
# 47              0.000892              0.000892
# 48              0.000694              0.000694
# 49              0.000496              0.000496

# %% [markdown]
# ### Train result based on Evaluation Data

# %%
from IPython.display import Image, display
image_path = results_path + '/results.png'

display(Image(filename=image_path, width=800, height=600))

# %%
image_path = results_path + '/confusion_matrix.png'

display(Image(filename=image_path, width=800, height=600))

# %%
image_path = results_path + '/F1_curve.png'

display(Image(filename=image_path, width=800, height=600))

# %%
image_path = results_path + '/P_curve.png'

display(Image(filename=image_path, width=800, height=600))

# %%
image_path = results_path + '/PR_curve.png'

display(Image(filename=image_path, width=800, height=600))

# %%
image_path = results_path + '/R_curve.png'

display(Image(filename=image_path, width=800, height=600))
