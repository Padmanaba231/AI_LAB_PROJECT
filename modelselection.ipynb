# %%
results_path_v5 = "Model/YoloV5/yolov5/runs/train/exp"
results_path_v8 = "Model/YoloV8/ultralytics/runs/detect/train"

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## YoloV5

# %%
from IPython.display import Image, display
image_path = results_path_v5 + '/results.png'

display(Image(filename=image_path, width=800, height=600))

# %% [markdown]
# ## YoloV8

# %%
from IPython.display import Image, display
image_path = results_path_v8 + '/results.png'

display(Image(filename=image_path, width=800, height=600))

# %% [markdown]
# # F1 Score

# %% [markdown]
# ## YoloV5

# %%
image_path = results_path_v5 + '/F1_curve.png'

display(Image(filename=image_path, width=800, height=600))

# %% [markdown]
# ## YoloV8

# %%
image_path = results_path_v8 + '/F1_curve.png'

display(Image(filename=image_path, width=800, height=600))

# %% [markdown]
# # Precision

# %% [markdown]
# ## YoloV5

# %%
image_path = results_path_v5 + '/P_curve.png'

display(Image(filename=image_path, width=800, height=600))

# %% [markdown]
# ## YoloV8

# %%
image_path = results_path_v8 + '/P_curve.png'

display(Image(filename=image_path, width=800, height=600))

# %% [markdown]
# # Precision-Recall

# %% [markdown]
# ## YoloV5

# %%
image_path = results_path_v5 + '/PR_curve.png'

display(Image(filename=image_path, width=800, height=600))

# %% [markdown]
# ## YoloV8

# %%
image_path = results_path_v8 + '/PR_curve.png'

display(Image(filename=image_path, width=800, height=600))

# %% [markdown]
# # Recall-Confidence Curve

# %% [markdown]
# ## YoloV5

# %%
image_path = results_path_v5 + '/R_curve.png'

display(Image(filename=image_path, width=800, height=600))

# %%
image_path = results_path_v8 + '/R_curve.png'

display(Image(filename=image_path, width=800, height=600))

# %% [markdown]
# # Kesimpulan

# %% [markdown]
# Model YoloV5 memiliki kulaitas lebih bagus dan lebih stabil daripada model YoloV8. Karena hal ini, pada project ini akan menggunakan model YoloV5
